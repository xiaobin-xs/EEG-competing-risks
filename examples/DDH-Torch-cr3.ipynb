# %%
SEED = 4444
_EPSILON = 1e-08

# %%
import sys
sys.path.append('../auton-survival/')
sys.path.append('../ddh/')

import pandas as pd
import numpy as np
import torch.nn as nn
import torch
from torch.utils.data import DataLoader
import torch.nn.functional as F
import os
from sklearn.model_selection import train_test_split
from tqdm import tqdm
from torch.utils.tensorboard import SummaryWriter
import datetime

from ddh_torch import DynamicDeepHitTorch
import import_data as impt
from utils_eval import c_index, brier_score
from utils_helper import f_get_boosted_trainset
from utils_helper import loss_Log_Likelihood, loss_Ranking, loss_RNN_Prediction
from utils_helper import f_get_risk_predictions, _f_get_pred
from utils_helper import save_checkpoint, load_checkpoint

# %%
## for reproducibility
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(SEED)

# %%
def model_eval(model, dataloader, device):
    model.eval()
    total_loss = 0
    Loss1, Loss2, Loss3 = 0, 0, 0

    for i, (b_data, b_data_mi, b_time, b_label, b_mask1, b_mask2, b_mask3) in enumerate(dataloader):
        b_data, _, b_time, b_label, b_mask1, b_mask2, b_mask3 = \
            b_data.float(), b_data_mi.float(), b_time.float(), b_label.float(), \
            b_mask1.float(), b_mask2.float(), b_mask3.float()
        b_data, b_time, b_label, b_mask1, b_mask2, b_mask3 = \
            b_data.to(device), b_time.to(device), b_label.to(device), \
            b_mask1.to(device), b_mask2.to(device), b_mask3.to(device)
        
        longitudinal_prediction, out = model(b_data)
        out = torch.concat([o.unsqueeze(1) for o in out], 1) # (B, num_Event, num_Category)
        loss1 = loss_Log_Likelihood(out, b_label, b_mask1, b_mask2)
        loss2 = loss_Ranking(out, b_time, b_label, b_mask3, num_Event, num_Category)
        loss3 = loss_RNN_Prediction(longitudinal_prediction, b_data)
        loss = alpha * loss1 + beta * loss2 + gamma * loss3
        
        total_loss += loss
        Loss1 += loss1
        Loss2 += loss2
        Loss3 += loss3
        
    return total_loss/len(dataloader), Loss1/len(dataloader), Loss2/len(dataloader), Loss3/len(dataloader)

# %% [markdown]
# ### Import Dataset

# %%
data_mode                   = 'EEG_cr3' # competing risk with 3 causes
seed                        = SEED

##### IMPORT DATASET
'''
    num_Category            = max event/censoring time * 1.2
    num_Event               = number of evetns i.e. len(np.unique(label))-1
    max_length              = maximum number of measurements
    x_dim                   = data dimension including delta (1 + num_features)
    x_dim_cont              = dim of continuous features
    x_dim_bin               = dim of binary features
    mask1, mask2, mask3     = used for cause-specific network (FCNet structure)
'''

if data_mode == 'EEG_cr3':
    (x_dim, x_dim_cont, x_dim_bin), (data, time, label, time_original, time_to_last), \
        (mask1, mask2, mask3), (data_mi), trans_discrete_time = \
                    impt.import_dataset('../../eeg/competing-risk/EEG_processed_data_long_by_death_cat_exclude_3.csv')
    
    # This must be changed depending on the datasets, prediction/evaliation times of interest
    pred_time = [6, 12] # prediction time (in hours)
    eval_time = [12, 24,] # hours evaluation time (for C-index and Brier-Score)
else:
    print ('ERROR:  DATA_MODE NOT FOUND !!!')

_, num_Event, num_Category  = np.shape(mask1)  # dim of mask3: [subj, Num_Event, Num_Category]
max_length                  = np.shape(data)[1]


# file_path = '{}_{}'.format(data_mode, seed)

# if not os.path.exists(file_path):
#     os.makedirs(file_path)
    
num_Event, num_Category, max_length
# Out:
# /heinz-georgenas/anaconda3/envs/py39xiaobin/lib/python3.9/site-packages/pycox/preprocessing/label_transforms.py:113: UserWarning: Calling fit method, when 'cuts' are already defined. Leaving cuts unchanged.
#   warnings.warn("Calling fit method, when 'cuts' are already defined. Leaving cuts unchanged.")
# (3, 120, 12)

# %% [markdown]
# ### Set Hyper-Parameters

# %%
from sklearn.model_selection import ParameterGrid
model_name = 'ddh_eeg_cr3'
param_grid = {'dropout': [0.2, 0.4], 
              'lr_train': [1e-4, 5e-4, 1e-3],
              'beta': [0.5, 1, 5],
              'gamma': [0.05, 0.1, 0.5],
             }
param_grid_list = list(ParameterGrid(param_grid))
print(len(param_grid_list))
param_grid_list
# Out:
# 54
# [{'beta': 0.5, 'dropout': 0.2, 'gamma': 0.05, 'lr_train': 0.0001},
#  {'beta': 0.5, 'dropout': 0.2, 'gamma': 0.05, 'lr_train': 0.0005},
#  {'beta': 0.5, 'dropout': 0.2, 'gamma': 0.05, 'lr_train': 0.001},
#  {'beta': 0.5, 'dropout': 0.2, 'gamma': 0.1, 'lr_train': 0.0001},
#  {'beta': 0.5, 'dropout': 0.2, 'gamma': 0.1, 'lr_train': 0.0005},
#  {'beta': 0.5, 'dropout': 0.2, 'gamma': 0.1, 'lr_train': 0.001},
#  {'beta': 0.5, 'dropout': 0.2, 'gamma': 0.5, 'lr_train': 0.0001},
#  {'beta': 0.5, 'dropout': 0.2, 'gamma': 0.5, 'lr_train': 0.0005},
#  {'beta': 0.5, 'dropout': 0.2, 'gamma': 0.5, 'lr_train': 0.001},
#  {'beta': 0.5, 'dropout': 0.4, 'gamma': 0.05, 'lr_train': 0.0001},
#  {'beta': 0.5, 'dropout': 0.4, 'gamma': 0.05, 'lr_train': 0.0005},
#  {'beta': 0.5, 'dropout': 0.4, 'gamma': 0.05, 'lr_train': 0.001},
#  {'beta': 0.5, 'dropout': 0.4, 'gamma': 0.1, 'lr_train': 0.0001},
#  {'beta': 0.5, 'dropout': 0.4, 'gamma': 0.1, 'lr_train': 0.0005},
#  {'beta': 0.5, 'dropout': 0.4, 'gamma': 0.1, 'lr_train': 0.001},
#  {'beta': 0.5, 'dropout': 0.4, 'gamma': 0.5, 'lr_train': 0.0001},
#  {'beta': 0.5, 'dropout': 0.4, 'gamma': 0.5, 'lr_train': 0.0005},
#  {'beta': 0.5, 'dropout': 0.4, 'gamma': 0.5, 'lr_train': 0.001},
#  {'beta': 1, 'dropout': 0.2, 'gamma': 0.05, 'lr_train': 0.0001},
#  {'beta': 1, 'dropout': 0.2, 'gamma': 0.05, 'lr_train': 0.0005},
#  {'beta': 1, 'dropout': 0.2, 'gamma': 0.05, 'lr_train': 0.001},
#  {'beta': 1, 'dropout': 0.2, 'gamma': 0.1, 'lr_train': 0.0001},
#  {'beta': 1, 'dropout': 0.2, 'gamma': 0.1, 'lr_train': 0.0005},
#  {'beta': 1, 'dropout': 0.2, 'gamma': 0.1, 'lr_train': 0.001},
#  {'beta': 1, 'dropout': 0.2, 'gamma': 0.5, 'lr_train': 0.0001},
#  {'beta': 1, 'dropout': 0.2, 'gamma': 0.5, 'lr_train': 0.0005},
#  {'beta': 1, 'dropout': 0.2, 'gamma': 0.5, 'lr_train': 0.001},
#  {'beta': 1, 'dropout': 0.4, 'gamma': 0.05, 'lr_train': 0.0001},
#  {'beta': 1, 'dropout': 0.4, 'gamma': 0.05, 'lr_train': 0.0005},
#  {'beta': 1, 'dropout': 0.4, 'gamma': 0.05, 'lr_train': 0.001},
#  {'beta': 1, 'dropout': 0.4, 'gamma': 0.1, 'lr_train': 0.0001},
#  {'beta': 1, 'dropout': 0.4, 'gamma': 0.1, 'lr_train': 0.0005},
#  {'beta': 1, 'dropout': 0.4, 'gamma': 0.1, 'lr_train': 0.001},
#  {'beta': 1, 'dropout': 0.4, 'gamma': 0.5, 'lr_train': 0.0001},
#  {'beta': 1, 'dropout': 0.4, 'gamma': 0.5, 'lr_train': 0.0005},
#  {'beta': 1, 'dropout': 0.4, 'gamma': 0.5, 'lr_train': 0.001},
#  {'beta': 5, 'dropout': 0.2, 'gamma': 0.05, 'lr_train': 0.0001},
#  {'beta': 5, 'dropout': 0.2, 'gamma': 0.05, 'lr_train': 0.0005},
#  {'beta': 5, 'dropout': 0.2, 'gamma': 0.05, 'lr_train': 0.001},
#  {'beta': 5, 'dropout': 0.2, 'gamma': 0.1, 'lr_train': 0.0001},
#  {'beta': 5, 'dropout': 0.2, 'gamma': 0.1, 'lr_train': 0.0005},
#  {'beta': 5, 'dropout': 0.2, 'gamma': 0.1, 'lr_train': 0.001},
#  {'beta': 5, 'dropout': 0.2, 'gamma': 0.5, 'lr_train': 0.0001},
#  {'beta': 5, 'dropout': 0.2, 'gamma': 0.5, 'lr_train': 0.0005},
#  {'beta': 5, 'dropout': 0.2, 'gamma': 0.5, 'lr_train': 0.001},
#  {'beta': 5, 'dropout': 0.4, 'gamma': 0.05, 'lr_train': 0.0001},
#  {'beta': 5, 'dropout': 0.4, 'gamma': 0.05, 'lr_train': 0.0005},
#  {'beta': 5, 'dropout': 0.4, 'gamma': 0.05, 'lr_train': 0.001},
#  {'beta': 5, 'dropout': 0.4, 'gamma': 0.1, 'lr_train': 0.0001},
#  {'beta': 5, 'dropout': 0.4, 'gamma': 0.1, 'lr_train': 0.0005},
#  {'beta': 5, 'dropout': 0.4, 'gamma': 0.1, 'lr_train': 0.001},
#  {'beta': 5, 'dropout': 0.4, 'gamma': 0.5, 'lr_train': 0.0001},
#  {'beta': 5, 'dropout': 0.4, 'gamma': 0.5, 'lr_train': 0.0005},
#  {'beta': 5, 'dropout': 0.4, 'gamma': 0.5, 'lr_train': 0.001}]

# %%
boost_mode = 'ON' #{'ON', 'OFF'}

param = {'batch_size': 32,

         'num_epoch_burn_in': 20,
         'num_epoch': 100,

         'dropout': 0.2, # 1 - keep_prob
         'lr_train': 1e-4,

         'hidden_rnn': 64,
         'hidden_dim_FC': 64,
         'layers_rnn': 2,
         'hidden_att': 2,
         'hidden_cs' : 2,

         'alpha' :1.0,
         'beta'  :1,
         'gamma' :0.1
        }


batch_size = param['batch_size']
num_epoch  = param['num_epoch']

dropout    = param['dropout']
lr_train   = param['lr_train']

hidden_rnn = param['hidden_rnn']
hidden_dim_FC = param['hidden_dim_FC']
layers_rnn = param['layers_rnn']
hidden_att = param['hidden_att']
hidden_cs = param['hidden_cs']

alpha      = param['alpha']
beta       = param['beta']
gamma      = param['gamma']

device     = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# ### Split Dataset into Train/Valid/Test Sets

# %%
### TRAINING-TESTING SPLIT
(tr_data,te_data, tr_data_mi, te_data_mi, tr_time,te_time, tr_label,te_label, tr_time_orinal,te_time_original,
 tr_time_to_last,te_time_to_last,
 tr_mask1,te_mask1, tr_mask2,te_mask2, tr_mask3,te_mask3) = \
        train_test_split(data, data_mi, time, label, time_original, time_to_last,
                         mask1, mask2, mask3, test_size=0.2, stratify=label, random_state=seed) 

(tr_data,va_data, tr_data_mi, va_data_mi, tr_time,va_time, tr_label,va_label, tr_time_orinal,va_time_original,
 tr_time_to_last, va_time_to_last,
 tr_mask1,va_mask1, tr_mask2,va_mask2, tr_mask3,va_mask3) = \
        train_test_split(tr_data, tr_data_mi, tr_time, tr_label, tr_time_orinal, tr_time_to_last,
                         tr_mask1, tr_mask2, tr_mask3, test_size=0.2, stratify=tr_label, random_state=seed) 

if boost_mode == 'ON':
    tr_data, tr_data_mi, tr_time, tr_label, tr_mask1, tr_mask2, tr_mask3 = \
            f_get_boosted_trainset(tr_data, tr_data_mi, tr_time, tr_label, tr_mask1, tr_mask2, tr_mask3)

# %%
tr_loader = DataLoader(list(zip(tr_data, tr_data_mi, tr_time, tr_label, tr_mask1, tr_mask2, tr_mask3)), 
                       batch_size=batch_size, shuffle=True)

va_loader = DataLoader(list(zip(va_data, va_data_mi, va_time, va_label, va_mask1, va_mask2, va_mask3)), 
                       batch_size=batch_size, shuffle=False)

te_loader = DataLoader(list(zip(te_data, te_data_mi, te_time, te_label, te_mask1, te_mask2, te_mask3)), 
                       batch_size=batch_size, shuffle=False)

# %% [markdown]
# ### Train the Network

# %% [markdown]
# This implementation does not consider missing values.

# %%
num_Event
# Out:
# 3

# %%
pred_time = [6, 12]
eval_time = [24, 48, 72]

# %%
import pdb

Best_C_Index = 0


for params in tqdm(param_grid_list):
    dropout = params['dropout']
    lr_train = params['lr_train']
    beta = params['beta']
    gamma = params['gamma']
    print('='*80, '\n', params)

    model = \
        DynamicDeepHitTorch(input_dim  = x_dim,
                            output_dim = num_Category,
                            layers_rnn = param['layers_rnn'],
                            hidden_rnn = param['hidden_rnn'],
                            long_param = {'layers': 2*[param['hidden_dim_FC']], 'dropout': dropout}, 
                            att_param  = {'layers': param['hidden_att']*[param['hidden_dim_FC']], 'dropout': dropout}, 
                            cs_param   = {'layers': param['hidden_cs']*[param['hidden_dim_FC']], 'dropout': dropout},
                            risks      = num_Event
                           )
    optimizer_burn_in = torch.optim.Adam(model.parameters(), lr = lr_train)
    optimizer = torch.optim.Adam(model.parameters(), lr = lr_train)


    model.train()
    model.to(device)

    min_valid = 0.1
    early_stop_patience = 10
    ep = 0 # for tracking early stopping

    experiment_runtime = datetime.datetime.now().strftime('%Y%m%d_%H%M')
    tensorboard_string_extension = f"{model_name}_{SEED}"
    tensorboard_string_extension += f"_alpha{alpha}_beta{beta}_gamma{gamma}_BSZ{batch_size}_Lr{lr_train}"
    tensorboard_string_extension += f"_hiddenRNN{hidden_rnn}_hiddenFC{hidden_dim_FC}"
    tensorboard_string_extension += f"_layersRNN{layers_rnn}_hiddenAtt{hidden_att}_hiddenCS{hidden_cs}"
    tensorboard_string_extension += f"_dropout{dropout}"
    tensorboard_string_extension += "_" + experiment_runtime
    tensorboard_filename = tensorboard_string_extension
    writer = SummaryWriter(f"runs/{model_name}/{tensorboard_filename}")


    for epoch in range(param['num_epoch_burn_in']):
        model.train()
        for i, (b_data, b_data_mi, b_time, b_label, b_mask1, b_mask2, b_mask3) in enumerate(tr_loader):
            b_data, _, b_time, b_label, b_mask1, b_mask2, b_mask3 = \
                b_data.float(), b_data_mi.float(), b_time.float(), b_label.float(), \
                b_mask1.float(), b_mask2.float(), b_mask3.float()
            b_data, b_time, b_label, b_mask1, b_mask2, b_mask3 = \
                b_data.to(device), b_time.to(device), b_label.to(device), \
                b_mask1.to(device), b_mask2.to(device), b_mask3.to(device)

            longitudinal_prediction, out = model(b_data)
            out = torch.concat([o.unsqueeze(1) for o in out], 1) # (B, num_Event, num_Category)

            # loss1 = loss_Log_Likelihood(out, b_label, b_mask1, b_mask2)
            # loss2 = loss_Ranking(out, b_time, b_label, b_mask3, num_Event, num_Category)
            loss3 = loss_RNN_Prediction(longitudinal_prediction, b_data)
            tr_loss = loss3

            optimizer_burn_in.zero_grad()
            tr_loss.backward()
            optimizer_burn_in.step()


    for epoch in range(num_epoch):
        model.train()
        for i, (b_data, b_data_mi, b_time, b_label, b_mask1, b_mask2, b_mask3) in enumerate(tr_loader):
            b_data, _, b_time, b_label, b_mask1, b_mask2, b_mask3 = \
                b_data.float(), b_data_mi.float(), b_time.float(), b_label.float(), \
                b_mask1.float(), b_mask2.float(), b_mask3.float()
            b_data, b_time, b_label, b_mask1, b_mask2, b_mask3 = \
                b_data.to(device), b_time.to(device), b_label.to(device), \
                b_mask1.to(device), b_mask2.to(device), b_mask3.to(device)

            longitudinal_prediction, out = model(b_data)
            out = torch.concat([o.unsqueeze(1) for o in out], 1) # (B, num_Event, num_Category)

            loss1 = loss_Log_Likelihood(out, b_label, b_mask1, b_mask2)
            loss2 = loss_Ranking(out, b_time, b_label, b_mask3, num_Event, num_Category)
            loss3 = loss_RNN_Prediction(longitudinal_prediction, b_data)
            tr_loss = alpha * loss1 + beta * loss2 + gamma * loss3

            optimizer.zero_grad()
            tr_loss.backward()
            optimizer.step()

        model.eval()
        tr_loss, tr_loss1, tr_loss2, tr_loss3 = model_eval(model, tr_loader, device)
        va_loss, va_loss1, va_loss2, va_loss3 = model_eval(model, va_loader, device)

        ### VALIDATION  (based on average C-index of our interest)
        risk_all = f_get_risk_predictions(model, va_data, pred_time, eval_time, device)

        for p, p_time in enumerate(pred_time):
            pred_horizon = int(p_time)
            val_result1 = np.zeros([num_Event, len(eval_time)])

            for t, t_time in enumerate(eval_time):                
                eval_horizon = int(t_time) + pred_horizon
                for k in range(num_Event):
                    val_result1[k, t] = c_index(risk_all[k][:, p, t], va_time, (va_label[:,0] == k+1).astype(int), eval_horizon) #-1 for no event (not comparable)

            if p == 0:
                val_final1 = val_result1
            else:
                val_final1 = np.append(val_final1, val_result1, axis=0)

        tmp_valid = np.mean(val_final1)

        if tmp_valid >  min_valid:
            ep = 0
            min_valid = tmp_valid
            save_checkpoint(f"checkpoints/{model_name}/{writer.get_logdir().split('/')[-1]}_{SEED}.pt", model, optimizer, va_loss)
            print( 'updated.... average c-index = ' + str('%.4f' %(tmp_valid)))
        else:
            ep += 1  
            print("Counter {} of {}".format(ep, early_stop_patience))

        if ep >= early_stop_patience:
            print("Early stopping with best_cindex: {:.4f}".format(min_valid), 
                  "and val_cindex for this epoch: {:.4f}".format(tmp_valid))
            break

        # Tensorboard
        writer.add_scalar("Loss-Training/Loss", tr_loss, epoch)
        writer.add_scalar("Loss-Training/NLL Loss", tr_loss1, epoch)
        writer.add_scalar("Loss-Training/Ranking Loss", tr_loss2, epoch)
        writer.add_scalar("Loss-Training/LSTM MSELoss", tr_loss3, epoch)

        writer.add_scalar("Loss-Validation/Loss", va_loss, epoch)
        writer.add_scalar("Loss-Validation/NLL Loss", va_loss1, epoch)
        writer.add_scalar("Loss-Validation/Ranking Loss", va_loss2, epoch)
        writer.add_scalar("Loss-Validation/LSTM MSELoss", va_loss3, epoch)

        writer.add_scalar("C-index/Validation Avg C-index", min_valid, epoch)

        print('epoch {}, tr_loss: {:.4f}, va_loss: {:.4f}, va c-index: {:.4f}'.\
                      format(epoch+1, tr_loss, va_loss, tmp_valid))
        
    if min_valid > Best_C_Index:
        Best_C_Index = min_valid
        print('Better valudation c-index!!!')
        print(writer.get_logdir().split('/')[-1])
# Out:
#   0%|                                                                | 0/54 [00:00<?, ?it/s]
# ================================================================================
#  {'beta': 0.5, 'dropout': 0.2, 'gamma': 0.05, 'lr_train': 0.0001}
# updated.... average c-index = 0.6208
# epoch 1, tr_loss: 31.4881, va_loss: 36.2923, va c-index: 0.6208
# Counter 1 of 10
# epoch 2, tr_loss: 31.3619, va_loss: 36.2717, va c-index: 0.6153
# updated.... average c-index = 0.6245
# epoch 3, tr_loss: 29.6774, va_loss: 35.9038, va c-index: 0.6245
# updated.... average c-index = 0.6292
# epoch 4, tr_loss: 29.3677, va_loss: 35.8742, va c-index: 0.6292
# updated.... average c-index = 0.6346
# epoch 5, tr_loss: 29.0159, va_loss: 35.6508, va c-index: 0.6346
# updated.... average c-index = 0.6393
# epoch 6, tr_loss: 28.3746, va_loss: 35.5731, va c-index: 0.6393
# updated.... average c-index = 0.6479
# epoch 7, tr_loss: 28.6759, va_loss: 35.6991, va c-index: 0.6479
# updated.... average c-index = 0.6496
# epoch 8, tr_loss: 28.1240, va_loss: 35.6501, va c-index: 0.6496
# updated.... average c-index = 0.6568
# epoch 9, tr_loss: 27.8617, va_loss: 35.6734, va c-index: 0.6568
# Counter 1 of 10
# epoch 10, tr_loss: 27.6488, va_loss: 36.0836, va c-index: 0.6518
# updated.... average c-index = 0.6691
# epoch 11, tr_loss: 27.2762, va_loss: 35.5943, va c-index: 0.6691
# updated.... average c-index = 0.6729
# epoch 12, tr_loss: 26.8798, va_loss: 35.7178, va c-index: 0.6729
# updated.... average c-index = 0.6840
# epoch 13, tr_loss: 26.8071, va_loss: 35.4873, va c-index: 0.6840
# Counter 1 of 10
# epoch 14, tr_loss: 26.5252, va_loss: 35.6703, va c-index: 0.6736
# Counter 2 of 10
# epoch 15, tr_loss: 26.0965, va_loss: 35.4199, va c-index: 0.6736
# Counter 3 of 10
# epoch 16, tr_loss: 25.7722, va_loss: 35.7546, va c-index: 0.6594
# Counter 4 of 10
# epoch 17, tr_loss: 25.8694, va_loss: 36.1706, va c-index: 0.6781
# Counter 5 of 10
# epoch 18, tr_loss: 25.2460, va_loss: 36.0569, va c-index: 0.6759
# Counter 6 of 10
# epoch 19, tr_loss: 24.9543, va_loss: 36.6133, va c-index: 0.6756
# Counter 7 of 10
# epoch 20, tr_loss: 24.4977, va_loss: 35.8519, va c-index: 0.6806
# Counter 8 of 10
# epoch 21, tr_loss: 24.1379, va_loss: 36.1748, va c-index: 0.6782
# Counter 9 of 10
# epoch 22, tr_loss: 23.7776, va_loss: 36.3688, va c-index: 0.6756
#   2%|▉                                                    | 1/54 [02:18<2:02:39, 138.86s/it]
# Counter 10 of 10
# Early stopping with best_cindex: 0.6840 and val_cindex for this epoch: 0.6767
# Better valudation c-index!!!
# ddh_eeg_cr3_4444_alpha1.0_beta0.5_gamma0.05_BSZ32_Lr0.0001_hiddenRNN64_hiddenFC64_layersRNN2_hiddenAtt2_hiddenCS2_dropout0.2_20230314_1025
# ================================================================================
#  {'beta': 0.5, 'dropout': 0.2, 'gamma': 0.05, 'lr_train': 0.0005}
# updated.... average c-index = 0.5652
# epoch 1, tr_loss: 26.6152, va_loss: 39.4735, va c-index: 0.5652
# updated.... average c-index = 0.6413
# epoch 2, tr_loss: 23.4386, va_loss: 39.3555, va c-index: 0.6413
# updated.... average c-index = 0.6473
# epoch 3, tr_loss: 21.4149, va_loss: 38.4729, va c-index: 0.6473
# updated.... average c-index = 0.6701
# epoch 4, tr_loss: 20.1238, va_loss: 38.8832, va c-index: 0.6701
# Counter 1 of 10
# epoch 5, tr_loss: 20.2581, va_loss: 39.1446, va c-index: 0.6335
# Counter 2 of 10
# epoch 6, tr_loss: 22.6350, va_loss: 40.9687, va c-index: 0.6456
# Counter 3 of 10
# epoch 7, tr_loss: 22.8216, va_loss: 36.5716, va c-index: 0.6659
# Counter 4 of 10
# epoch 8, tr_loss: 20.2180, va_loss: 34.9906, va c-index: 0.6555
# Counter 5 of 10
# epoch 9, tr_loss: 20.6485, va_loss: 36.5786, va c-index: 0.6700
# Counter 6 of 10
# epoch 10, tr_loss: 21.2787, va_loss: 36.3954, va c-index: 0.6371
# Counter 7 of 10
# epoch 11, tr_loss: 20.4698, va_loss: 36.2532, va c-index: 0.6627
# Counter 8 of 10
# epoch 12, tr_loss: 22.6529, va_loss: 36.5916, va c-index: 0.6677
# Counter 9 of 10
# epoch 13, tr_loss: 17.8898, va_loss: 36.9659, va c-index: 0.6675
#   4%|█▉                                                   | 2/54 [03:57<1:39:46, 115.13s/it]
# Counter 10 of 10
# Early stopping with best_cindex: 0.6701 and val_cindex for this epoch: 0.5862
# ================================================================================
#  {'beta': 0.5, 'dropout': 0.2, 'gamma': 0.05, 'lr_train': 0.001}
# updated.... average c-index = 0.6731
# epoch 1, tr_loss: 27.6562, va_loss: 36.3823, va c-index: 0.6731
# Counter 1 of 10
# epoch 2, tr_loss: 27.4547, va_loss: 36.5253, va c-index: 0.6299
# Counter 2 of 10
# epoch 3, tr_loss: 31.1247, va_loss: 40.0557, va c-index: 0.5742
# Counter 3 of 10
# epoch 4, tr_loss: 27.7220, va_loss: 35.1720, va c-index: 0.6481
# Counter 4 of 10
# epoch 5, tr_loss: 26.8663, va_loss: 36.7862, va c-index: 0.5916
# Counter 5 of 10
# epoch 6, tr_loss: 27.3393, va_loss: 38.2245, va c-index: 0.6081
# Counter 6 of 10
# epoch 7, tr_loss: 25.9059, va_loss: 36.6620, va c-index: 0.6693
# Counter 7 of 10
# epoch 8, tr_loss: 24.7103, va_loss: 36.7114, va c-index: 0.6585
# Counter 8 of 10
# epoch 9, tr_loss: 25.5206, va_loss: 37.2442, va c-index: 0.6345
# Counter 9 of 10
# epoch 10, tr_loss: 23.4405, va_loss: 37.2313, va c-index: 0.6722
#   6%|███                                                   | 3/54 [05:18<1:24:33, 99.47s/it]
# Counter 10 of 10
# Early stopping with best_cindex: 0.6731 and val_cindex for this epoch: 0.6683
# ================================================================================
#  {'beta': 0.5, 'dropout': 0.2, 'gamma': 0.1, 'lr_train': 0.0001}
# updated.... average c-index = 0.5502
# epoch 1, tr_loss: 52.4227, va_loss: 62.9614, va c-index: 0.5502
# updated.... average c-index = 0.6379
# epoch 2, tr_loss: 51.5424, va_loss: 62.9606, va c-index: 0.6379
# Counter 1 of 10
# epoch 3, tr_loss: 50.8352, va_loss: 62.3518, va c-index: 0.6235
# Counter 2 of 10
# epoch 4, tr_loss: 50.1322, va_loss: 62.6174, va c-index: 0.5845
# Counter 3 of 10
# epoch 5, tr_loss: 50.2574, va_loss: 62.9095, va c-index: 0.5626
# Counter 4 of 10
# epoch 6, tr_loss: 49.3446, va_loss: 62.8156, va c-index: 0.5829
# Counter 5 of 10
# epoch 7, tr_loss: 49.1829, va_loss: 62.6899, va c-index: 0.6079
# Counter 6 of 10
# epoch 8, tr_loss: 48.1104, va_loss: 62.5574, va c-index: 0.6116
# Counter 7 of 10
# epoch 9, tr_loss: 48.2718, va_loss: 63.0557, va c-index: 0.6197
# Counter 8 of 10
# epoch 10, tr_loss: 46.9648, va_loss: 62.2535, va c-index: 0.6297
# updated.... average c-index = 0.6442
# epoch 11, tr_loss: 47.0578, va_loss: 62.5442, va c-index: 0.6442
# Counter 1 of 10
# epoch 12, tr_loss: 47.0112, va_loss: 63.3092, va c-index: 0.6336
# Counter 2 of 10
# epoch 13, tr_loss: 45.7010, va_loss: 63.1296, va c-index: 0.6426
# Counter 3 of 10
# epoch 14, tr_loss: 45.1934, va_loss: 63.3901, va c-index: 0.6419
# updated.... average c-index = 0.6563
# epoch 15, tr_loss: 45.8014, va_loss: 64.0668, va c-index: 0.6563
# Counter 1 of 10
# epoch 16, tr_loss: 44.1022, va_loss: 63.5433, va c-index: 0.6542
# updated.... average c-index = 0.6577
# epoch 17, tr_loss: 43.4533, va_loss: 63.7625, va c-index: 0.6577
# updated.... average c-index = 0.6628
# epoch 18, tr_loss: 42.0404, va_loss: 63.9969, va c-index: 0.6628
# Counter 1 of 10
# epoch 19, tr_loss: 43.2112, va_loss: 64.1985, va c-index: 0.6469
# updated.... average c-index = 0.6640
# epoch 20, tr_loss: 41.3883, va_loss: 64.7159, va c-index: 0.6640
# Counter 1 of 10
# epoch 21, tr_loss: 40.5323, va_loss: 64.3381, va c-index: 0.6635
# updated.... average c-index = 0.6690
# epoch 22, tr_loss: 39.6779, va_loss: 64.9103, va c-index: 0.6690
# Counter 1 of 10
# epoch 23, tr_loss: 38.5585, va_loss: 64.3891, va c-index: 0.6569
# updated.... average c-index = 0.6760
# epoch 24, tr_loss: 37.4885, va_loss: 65.0342, va c-index: 0.6760
# Counter 1 of 10
# epoch 25, tr_loss: 36.6405, va_loss: 65.0301, va c-index: 0.6717
# Counter 2 of 10
# epoch 26, tr_loss: 35.3550, va_loss: 65.3320, va c-index: 0.6753
# updated.... average c-index = 0.6815
# epoch 27, tr_loss: 34.0114, va_loss: 64.6448, va c-index: 0.6815
# Counter 1 of 10
# epoch 28, tr_loss: 33.9096, va_loss: 65.0916, va c-index: 0.6750
# Counter 2 of 10
# epoch 29, tr_loss: 32.3969, va_loss: 66.1753, va c-index: 0.6715
# Counter 3 of 10
# epoch 30, tr_loss: 31.5600, va_loss: 65.8912, va c-index: 0.6616
# Counter 4 of 10
# epoch 31, tr_loss: 30.4615, va_loss: 65.7607, va c-index: 0.6652
# Counter 5 of 10
# epoch 32, tr_loss: 29.2614, va_loss: 66.9808, va c-index: 0.6775
# Counter 6 of 10
# epoch 33, tr_loss: 28.7554, va_loss: 65.0185, va c-index: 0.6737
# updated.... average c-index = 0.6913
# epoch 34, tr_loss: 28.0118, va_loss: 65.8848, va c-index: 0.6913
# Counter 1 of 10
# epoch 35, tr_loss: 26.4930, va_loss: 65.7740, va c-index: 0.6854
# Counter 2 of 10
# epoch 36, tr_loss: 26.0645, va_loss: 66.9353, va c-index: 0.6868
# Counter 3 of 10
# epoch 37, tr_loss: 25.8036, va_loss: 67.3702, va c-index: 0.6846
# Counter 4 of 10
# epoch 38, tr_loss: 24.9499, va_loss: 66.5228, va c-index: 0.6879
# Counter 5 of 10
# epoch 39, tr_loss: 24.6492, va_loss: 67.1474, va c-index: 0.6830
# updated.... average c-index = 0.6922
# epoch 40, tr_loss: 24.3487, va_loss: 65.5040, va c-index: 0.6922
# updated.... average c-index = 0.6942
# epoch 41, tr_loss: 23.8941, va_loss: 66.5615, va c-index: 0.6942
# Counter 1 of 10
# epoch 42, tr_loss: 24.0587, va_loss: 67.7729, va c-index: 0.6728
# updated.... average c-index = 0.6990
# epoch 43, tr_loss: 22.8308, va_loss: 67.5374, va c-index: 0.6990
# updated.... average c-index = 0.7048
# epoch 44, tr_loss: 23.3086, va_loss: 65.5592, va c-index: 0.7048
# Counter 1 of 10
# epoch 45, tr_loss: 22.7389, va_loss: 66.7687, va c-index: 0.7003
# updated.... average c-index = 0.7066
# epoch 46, tr_loss: 22.3319, va_loss: 66.5814, va c-index: 0.7066
# updated.... average c-index = 0.7141
# epoch 47, tr_loss: 21.9322, va_loss: 68.8490, va c-index: 0.7141
# Counter 1 of 10
# epoch 48, tr_loss: 23.7612, va_loss: 66.2221, va c-index: 0.7102
# Counter 2 of 10
# epoch 49, tr_loss: 22.5308, va_loss: 68.1515, va c-index: 0.6885
# Counter 3 of 10
# epoch 50, tr_loss: 21.7047, va_loss: 65.7217, va c-index: 0.7079
# Counter 4 of 10
# epoch 51, tr_loss: 21.7125, va_loss: 67.3474, va c-index: 0.7138
# Counter 5 of 10
# epoch 52, tr_loss: 22.0015, va_loss: 67.6518, va c-index: 0.7052
# updated.... average c-index = 0.7148
# epoch 53, tr_loss: 21.3539, va_loss: 66.5700, va c-index: 0.7148
# Counter 1 of 10
# epoch 54, tr_loss: 21.5803, va_loss: 66.6205, va c-index: 0.6944
# Counter 2 of 10
# epoch 55, tr_loss: 21.7402, va_loss: 69.4756, va c-index: 0.7072
# Counter 3 of 10
# epoch 56, tr_loss: 21.0548, va_loss: 66.8216, va c-index: 0.7108
# Counter 4 of 10
# epoch 57, tr_loss: 21.0235, va_loss: 67.4032, va c-index: 0.7142
# Counter 5 of 10
# epoch 58, tr_loss: 21.5169, va_loss: 65.2733, va c-index: 0.7066
# Counter 6 of 10
# epoch 59, tr_loss: 21.1519, va_loss: 66.7262, va c-index: 0.6990
# Counter 7 of 10
# epoch 60, tr_loss: 21.4882, va_loss: 63.9419, va c-index: 0.7099
# Counter 8 of 10
# epoch 61, tr_loss: 20.9930, va_loss: 65.1283, va c-index: 0.7029
# Counter 9 of 10
# epoch 62, tr_loss: 20.8548, va_loss: 64.9921, va c-index: 0.6939
#   7%|███▉                                                 | 4/54 [10:41<2:36:26, 187.73s/it]
# Counter 10 of 10
# Early stopping with best_cindex: 0.7148 and val_cindex for this epoch: 0.7010
# Better valudation c-index!!!
# ddh_eeg_cr3_4444_alpha1.0_beta0.5_gamma0.1_BSZ32_Lr0.0001_hiddenRNN64_hiddenFC64_layersRNN2_hiddenAtt2_hiddenCS2_dropout0.2_20230314_1030
# ================================================================================
#  {'beta': 0.5, 'dropout': 0.2, 'gamma': 0.1, 'lr_train': 0.0005}
# updated.... average c-index = 0.6007
# epoch 1, tr_loss: 43.2925, va_loss: 64.6533, va c-index: 0.6007
# updated.... average c-index = 0.6678
# epoch 2, tr_loss: 39.4649, va_loss: 64.0966, va c-index: 0.6678
# updated.... average c-index = 0.6801
# epoch 3, tr_loss: 37.5918, va_loss: 62.8580, va c-index: 0.6801
# Counter 1 of 10
# epoch 4, tr_loss: 36.3031, va_loss: 63.8553, va c-index: 0.6435
# updated.... average c-index = 0.6906
# epoch 5, tr_loss: 33.1156, va_loss: 61.7698, va c-index: 0.6906
# Counter 1 of 10
# epoch 6, tr_loss: 33.2436, va_loss: 63.6097, va c-index: 0.6740
# Counter 2 of 10
# epoch 7, tr_loss: 32.1694, va_loss: 65.5723, va c-index: 0.6810
# Counter 3 of 10
# epoch 8, tr_loss: 34.8416, va_loss: 68.0718, va c-index: 0.6100
# Counter 4 of 10
# epoch 9, tr_loss: 38.5435, va_loss: 64.4865, va c-index: 0.6448
# Counter 5 of 10
# epoch 10, tr_loss: 35.5192, va_loss: 62.0519, va c-index: 0.6544
# Counter 6 of 10
# epoch 11, tr_loss: 38.9388, va_loss: 63.5484, va c-index: 0.6441
# Counter 7 of 10
# epoch 12, tr_loss: 34.1248, va_loss: 61.5513, va c-index: 0.6862
# updated.... average c-index = 0.7022
# epoch 13, tr_loss: 30.6479, va_loss: 60.1039, va c-index: 0.7022
# Counter 1 of 10
# epoch 14, tr_loss: 31.2473, va_loss: 61.0968, va c-index: 0.6677
# Counter 2 of 10
# epoch 15, tr_loss: 32.3111, va_loss: 61.6584, va c-index: 0.6912
# updated.... average c-index = 0.7106
# epoch 16, tr_loss: 29.6018, va_loss: 59.3050, va c-index: 0.7106
# Counter 1 of 10
# epoch 17, tr_loss: 27.7746, va_loss: 60.6151, va c-index: 0.7053
# Counter 2 of 10
# epoch 18, tr_loss: 28.6437, va_loss: 60.8396, va c-index: 0.7040
# Counter 3 of 10
# epoch 19, tr_loss: 29.3646, va_loss: 63.3636, va c-index: 0.6903
# Counter 4 of 10
# epoch 20, tr_loss: 30.7517, va_loss: 65.6056, va c-index: 0.6129
# Counter 5 of 10
# epoch 21, tr_loss: 28.4911, va_loss: 61.9109, va c-index: 0.6933
# Counter 6 of 10
# epoch 22, tr_loss: 29.7874, va_loss: 58.8563, va c-index: 0.6697
# Counter 7 of 10
# epoch 23, tr_loss: 28.6086, va_loss: 58.5490, va c-index: 0.6724
# Counter 8 of 10
# epoch 24, tr_loss: 28.6089, va_loss: 64.5849, va c-index: 0.6066
# Counter 9 of 10
# epoch 25, tr_loss: 28.1801, va_loss: 64.2323, va c-index: 0.6355
#   9%|████▉                                                | 5/54 [13:11<2:22:24, 174.38s/it]
# Counter 10 of 10
# Early stopping with best_cindex: 0.
# epoch 7, tr_loss: 30.2705, va_loss: 36.3676, va c-index: 0.6019
# Counter 1 of 10
# epoch 8, tr_loss: 30.1848, va_loss: 35.9459, va c-index: 0.5969
# updated.... average c-index = 0.6076
# epoch 9, tr_loss: 29.9958, va_loss: 35.6708, va c-index: 0.6076
# Counter 1 of 10
# epoch 10, tr_loss: 29.6111, va_loss: 35.8344, va c-index: 0.6044
# updated.... average c-index = 0.6185
# epoch 11, tr_loss: 29.7520, va_loss: 35.9162, va c-index: 0.6185
# Counter 1 of 10
# epoch 12, tr_loss: 29.2452, va_loss: 35.7978, va c-index: 0.6170
# updated.... average c-index = 0.6190
# epoch 13, tr_loss: 28.8345, va_loss: 35.7667, va c-index: 0.6190
# Counter 1 of 10
# epoch 14, tr_loss: 28.5321, va_loss: 35.7266, va c-index: 0.6178
# updated.... average c-index = 0.6194
# epoch 15, tr_loss: 28.3953, va_loss: 35.7232, va c-index: 0.6194
# Counter 1 of 10
# epoch 16, tr_loss: 28.1041, va_loss: 35.8673, va c-index: 0.6187
# updated.... average c-index = 0.6215
# epoch 17, tr_loss: 27.7136, va_loss: 35.7279, va c-index: 0.6215
# Counter 1 of 10
# epoch 18, tr_loss: 27.3553, va_loss: 35.7454, va c-index: 0.6187
# Counter 2 of 10
# epoch 19, tr_loss: 27.3602, va_loss: 35.8933, va c-index: 0.6213
# updated.... average c-index = 0.6243
# epoch 20, tr_loss: 27.1805, va_loss: 35.8283, va c-index: 0.6243
# Counter 1 of 10
# epoch 21, tr_loss: 26.8998, va_loss: 35.9200, va c-index: 0.6224
# updated.... average c-index = 0.6278
# epoch 22, tr_loss: 26.6496, va_loss: 36.0357, va c-index: 0.6278
# Counter 1 of 10
# epoch 23, tr_loss: 25.9175, va_loss: 36.0568, va c-index: 0.6251
# Counter 2 of 10
# epoch 24, tr_loss: 26.3055, va_loss: 36.2000, va c-index: 0.6215
# Counter 3 of 10
# epoch 25, tr_loss: 25.9731, va_loss: 36.4170, va c-index: 0.6274
# updated.... average c-index = 0.6333
# epoch 26, tr_loss: 25.3746, va_loss: 36.4669, va c-index: 0.6333
# updated.... average c-index = 0.6337
# epoch 27, tr_loss: 25.0941, va_loss: 36.6952, va c-index: 0.6337
# updated.... average c-index = 0.6352
# epoch 28, tr_loss: 24.8535, va_loss: 36.6306, va c-index: 0.6352
# updated.... average c-index = 0.6368
# epoch 29, tr_loss: 24.3396, va_loss: 36.9478, va c-index: 0.6368
# updated.... average c-index = 0.6412
# epoch 30, tr_loss: 24.5234, va_loss: 36.9417, va c-index: 0.6412
# Counter 1 of 10
# epoch 31, tr_loss: 24.3476, va_loss: 37.2503, va c-index: 0.6384
# Counter 2 of 10
# epoch 32, tr_loss: 23.7265, va_loss: 37.4224, va c-index: 0.6382
# Counter 3 of 10
# epoch 33, tr_loss: 23.6079, va_loss: 37.5305, va c-index: 0.6396
# updated.... average c-index = 0.6458
# epoch 34, tr_loss: 23.1078, va_loss: 37.6720, va c-index: 0.6458
# updated.... average c-index = 0.6502
# epoch 35, tr_loss: 22.6497, va_loss: 37.7722, va c-index: 0.6502
/it]
# Counter 10 of 10
# Early stopping with best_cindex: 0.7032 and val_cindex for this epoch: 0.6989
# ================================================================================
#  {'beta': 0.5, 'dropout': 0.4, 'gamma': 0.05, 'lr_train': 0.001}
# updated.... average c-index = 0.5680
# epoch 1, tr_loss: 29.9795, va_loss: 36.2351, va c-index: 0.5680
# Counter 1 of 10
# epoch 2, tr_loss: 30.0637, va_loss: 36.8382, va c-index: 0.5328
# Counter 2 of 10
# epoch 3, tr_loss: 30.9675, va_loss: 37.0804, va c-index: 0.5608
# updated.... average c-index = 0.5925
# epoch 4, tr_loss: 28.0847, va_loss: 35.3005, va c-index: 0.5925
# updated.... average c-index = 0.6395
# epoch 5, tr_loss: 28.4998, va_loss: 35.5441, va c-index: 0.6395
# Counter 1 of 10
# epoch 6, tr_loss: 27.2722, va_loss: 34.5902, va c-index: 0.6056
# Counter 2 of 10
# epoch 7, tr_loss: 29.6923, va_loss: 37.9956, va c-index: 0.5555
# updated.... average c-index = 0.6533
# epoch 8, tr_loss: 26.7117, va_loss: 34.9916, va c-index: 0.6533
# Counter 1 of 10
# epoch 9, tr_loss: 29.6618, va_loss: 35.1613, va c-index: 0.6532
# Counter 2 of 10
# epoch 10, tr_loss: 29.1148, va_loss: 36.5236, va c-index: 0.5893
# updated.... average c-index = 0.6559
# epoch 11, tr_loss: 27.1892, va_loss: 35.9611, va c-index: 0.6559
# updated.... average c-index = 0.6670
# epoch 12, tr_loss: 26.8786, va_loss: 35.8274, va c-index: 0.6670
# Counter 1 of 10
# epoch 13, tr_loss: 24.8640, va_loss: 35.1345, va c-index: 0.6661
# updated.... average c-index = 0.6797
# epoch 14, tr_loss: 27.3280, va_loss: 35.5112, va c-index: 0.6797
# Counter 1 of 10
# epoch 15, tr_loss: 29.2616, va_loss: 38.8650, va c-index: 0.5698
# Counter 2 of 10
# epoch 16, tr_loss: 29.0032, va_loss: 41.0583, va c-index: 0.6241
# Counter 3 of 10
# epoch 17, tr_loss: 33.5092, va_loss: 43.6609, va c-index: 0.5996
# Counter 4 of 10
# epoch 18, tr_loss: 31.6702, va_loss: 39.2151, va c-index: 0.6023
# Counter 5 of 10
# epoch 19, tr_loss: 26.8932, va_loss: 37.1630, va c-index: 0.6498
# Counter 6 of 10
# epoch 20, tr_loss: 26.5103, va_loss: 38.2716, va c-index: 0.6690
# Counter 7 of 10
# epoch 21, tr_loss: 25.6840, va_loss: 36.6663, va c-index: 0.6514
# Counter 8 of 10
# epoch 22, tr_loss: 24.6936, va_loss: 35.6965, va c-index: 0.6731
# updated.... average c-index = 0.6857
# epoch 23, tr_loss: 23.2971, va_loss: 36.9997, va c-index: 0.6857
# Counter 1 of 10
# epoch 24, tr_loss: 24.8959, va_loss: 36.7675, va c-index: 0.6509
# updated.... average c-index = 0.7043
# epoch 25, tr_loss: 23.6890, va_loss: 36.7216, va c-index: 0.7043
# updated.... average c-index = 0.7233
# epoch 26, tr_loss: 23.2620, va_loss: 36.4566, va c-index: 0.7233
# Counter 1 of 10
# epoch 27, tr_loss: 23.1404, va_loss: 36.4557, va c-index: 0.7053
# Counter 2 of 10
# epoch 28, tr_loss: 24.8188, va_loss: 34.7480, va c-index: 0.7164
# Counter 3 of 10
# epoch 29, tr_loss: 25.6973, va_loss: 37.5899, va c-index: 0.7006
# Counter 4 of 10
# epoch 30, tr_loss: 25.5715, va_loss: 42.2383, va c-index: 0.7032
# Counter 5 of 10
# epoch 31, tr_loss: 25.2072, va_loss: 37.6570, va c-index: 0.6380
# Counter 6 of 10
# epoch 32, tr_loss: 22.9822, va_loss: 37.1025, va c-index: 0.6871
# Counter 7 of 10
# epoch 33, tr_loss: 22.5362, va_loss: 36.9118, va c-index: 0.6975
# Counter 8 of 10
# epoch 34, tr_loss: 27.7751, va_loss: 37.7345, va c-index: 0.6564
# Counter 9 of 10
# epoch 35, tr_loss: 22.6435, va_loss: 37.5166, va c-index: 0.6751
#  22%|███████████▌                                        | 12/54 [35:13<2:20:40, 200.98s/it]
# Counter 10 of 10
# Early stopping with best_cindex: 0.7233 and val_cindex for this epoch: 0.7053
# Better valudation c-index!!!
# ddh_eeg_cr3_4444_alpha1.0_beta0.5_gamma0.05_BSZ32_Lr0.001_hiddenRNN64_hiddenFC64_layersRNN2_hiddenAtt2_hiddenCS2_dropout0.4_20230314_1057
# ================================================================================
#  {'beta': 0.5, 'dropout': 0.4, 'gamma': 0.1, 'lr_train': 0.0001}
# updated.... average c-index = 0.5092
# epoch 1, tr_loss: 55.4419, va_loss: 63.4466, va c-index: 0.5092
# updated.... average c-index = 0.5768
# epoch 2, tr_loss: 52.6662, va_loss: 62.7995, va c-index: 0.5768
# updated.... average c-index = 0.5953
# epoch 3, tr_loss: 52.4902, va_loss: 62.5245, va c-index: 0.5953
# Counter 1 of 10
# epoch 4, tr_loss: 52.4294, va_loss: 62.7761, va c-index: 0.5858
# Counter 2 of 10
# epoch 5, tr_loss: 51.4651, va_loss: 62.6441, va c-index: 0.5857
# Counter 3 of 10
# epoch 6, tr_loss: 50.3353, va_loss: 62.7277, va c-index: 0.5913
# updated.... average c-index = 0.6002
# epoch 7, tr_loss: 50.5201, va_loss: 62.8509, va c-index: 0.6002
# Counter 1 of 10
# epoch 8, tr_loss: 50.2201, va_loss: 62.4101, va c-index: 0.5989
# Counter 2 of 10
# epoch 9, tr_loss: 49.7025, va_loss: 62.4496, va c-index: 0.5993
# updated.... average c-index = 0.6149
# epoch 10, tr_loss: 49.5787, va_loss: 62.5449, va c-index: 0.6149
# Counter 1 of 10
# epoch 11, tr_loss: 48.6969, va_loss: 62.1357, va c-index: 0.6107
# Counter 2 of 10
# epoch 12, tr_loss: 48.4130, va_loss: 62.2901, va c-index: 0.6134
# Counter 3 of 10
# epoch 13, tr_loss: 47.6450, va_loss: 62.4364, va c-index: 0.6080
# updated.... average c-index = 0.6241
# epoch 14, tr_loss: 47.4509, va_loss: 62.8950, va c-index: 0.6241
# Counter 1 of 10
# epoch 15, tr_loss: 46.9707, va_loss: 62.6040, va c-index: 0.6221
# Counter 2 of 10
# epoch 16, tr_loss: 46.5177, va_loss: 62.7815, va c-index: 0.6238
# updated.... average c-index = 0.6400
# epoch 17, tr_loss: 45.8379, va_loss: 62.6186, va c-index: 0.6400
# updated.... average c-index = 0.6420
# epoch 18, tr_loss: 45.5416, va_loss: 62.8894, va c-index: 0.6420
# updated.... average c-index = 0.6464
# epoch 19, tr_loss: 45.0500, va_loss: 63.0677, va c-index: 0.6464
# Counter 1 of 10
# epoch 20, tr_loss: 44.9578, va_loss: 63.4128, va c-index: 0.6396
# updated.... average c-index = 0.6481
# epoch 21, tr_loss: 44.3696, va_loss: 63.4118, va c-index: 0.6481
# updated.... average c-index = 0.6499
# epoch 22, tr_loss: 44.4091, va_loss: 63.4901, va c-index: 0.6499
# Counter 1 of 10
# epoch 23, tr_loss: 43.5681, va_loss: 63.9696, va c-index: 0.6422
# Counter 2 of 10
# epoch 24, tr_loss: 42.9389, va_loss: 63.8946, va c-index: 0.6475
# updated.... average c-index = 0.6519
# epoch 25, tr_loss: 42.3225, va_loss: 63.4714, va c-index: 0.6519
# Counter 1 of 10
# epoch 26, tr_loss: 42.1614, va_loss: 64.7335, va c-index: 0.6465
# Counter 2 of 10
# epoch 27, tr_loss: 41.1994, va_loss: 64.4285, va c-index: 0.6477
# Counter 3 of 10
# epoch 28, tr_loss: 40.4927, va_loss: 64.9696, va c-index: 0.6488
# updated.... average c-index = 0.6546
# epoch 29, tr_loss: 39.9517, va_loss: 64.6887, va c-index: 0.6546
# updated.... average c-index = 0.6596
# epoch 30, tr_loss: 39.4005, va_loss: 65.2174, va c-index: 0.6596
# Counter 1 of 10
# epoch 31, tr_loss: 38.5553, va_loss: 65.9391, va c-index: 0.6596
# Counter 2 of 10
# epoch 32, tr_loss: 37.7334, va_loss: 65.6194, va c-index: 0.6541
# Counter 3 of 10
# epoch 33, tr_loss: 37.3027, va_loss: 66.2086, va c-index: 0.6538
# Counter 4 of 10
# epoch 34, tr_loss: 36.3905, va_loss: 65.3720, va c-index: 0.6584
# Counter 5 of 10
# epoch 35, tr_loss: 35.5756, va_loss: 66.0663, va c-index: 0.6546
# Counter 6 of 10
# epoch 36, tr_loss: 34.6734, va_loss: 66.1931, va c-index: 0.6524
# Counter 7 of 10
# epoch 37, tr_loss: 34.0122, va_loss: 67.6802, va c-index: 0.6516
# Counter 8 of 10
# epoch 38, tr_loss: 32.5647, va_loss: 65.7421, va c-index: 0.6506
# Counter 9 of 10
# epoch 39, tr_loss: 31.5514, va_loss: 65.3871, va c-index: 0.6538
#  24%|████████████▌                                       | 13/54 [38:50<2:20:35, 205.74s/it]
# Counter 10 of 10
# Early stopping with best_cindex: 0.6596 and val_cindex for this epoch: 0.6572
# ================================================================================
#  {'beta': 0.5, 'dropout': 0.4, 'gamma': 0.1, 'lr_train': 0.0005}
# updated.... average c-index = 0.5441
# epoch 1, tr_loss: 50.2813, va_loss: 64.6702, va c-index: 0.5441
# updated.... average c-index = 0.5848
# epoch 2, tr_loss: 47.6517, va_loss: 64.0453, va c-index: 0.5848
# updated.... average c-index = 0.6300
# epoch 3, tr_loss: 46.5595, va_loss: 63.8572, va c-index: 0.6300
# updated.... average c-index = 0.6445
# epoch 4, tr_loss: 45.8733, va_loss: 64.0065, va c-index: 0.6445
# updated.... average c-index = 0.6502
# epoch 5, tr_loss: 43.0613, va_loss: 65.2085, va c-index: 0.6502
# updated.... average c-index = 0.6504
# epoch 6, tr_loss: 43.4562, va_loss: 64.6345, va c-index: 0.6504
# updated.... average c-index = 0.6740
# epoch 7, tr_loss: 43.9364, va_loss: 64.6217, va c-index: 0.6740
# updated.... average c-index = 0.6788
# epoch 8, tr_loss: 38.2162, va_loss: 65.9783, va c-index: 0.6788
# Counter 1 of 10
# epoch 9, tr_loss: 37.6965, va_loss: 65.5875, va c-index: 0.6733
# Counter 2 of 10
# epoch 10, tr_loss: 36.5624, va_loss: 65.6257, va c-index: 0.6640
# Counter 3 of 10
# epoch 11, tr_loss: 38.6070, va_loss: 62.9738, va c-index: 0.6700
# Counter 4 of 10
# epoch 12, tr_loss: 32.3499, va_loss: 66.9446, va c-index: 0.6722
# Counter 5 of 10
# epoch 13, tr_loss: 32.2622, va_loss: 63.8107, va c-index: 0.6684
# Counter 6 of 10
# epoch 14, tr_loss: 36.6209, va_loss: 70.2781, va c-index: 0.6646
# updated.... average c-index = 0.6921
# epoch 15, tr_loss: 31.5957, va_loss: 64.4877, va c-index: 0.6921
# Counter 1 of 10
# epoch 16, tr_loss: 33.6533, va_loss: 63.9640, va c-index: 0.6794
# Counter 2 of 10
# epoch 17, tr_loss: 31.7005, va_loss: 66.7991, va c-index: 0.6409
# Counter 3 of 10
# epoch 18, tr_loss: 28.7626, va_loss: 65.0207, va c-index: 0.6851
# Counter 4 of 10
# epoch 19, tr_loss: 28.9254, va_loss: 64.3517, va c-index: 0.6896
# Counter 5 of 10
# epoch 20, tr_loss: 28.4004, va_loss: 64.8109, va c-index: 0.6879
# Counter 6 of 10
# epoch 21, tr_loss: 27.7489, va_loss: 63.6678, va c-index: 0.6848
# Counter 7 of 10
# epoch 22, tr_loss: 29.4832, va_loss: 63.5214, va c-index: 0.6877
# Counter 8 of 10
# epoch 23, tr_loss: 29.3048, va_loss: 63.7218, va c-index: 0.6514
# updated.... average c-index = 0.6944
# epoch 24, tr_loss: 28.3932, va_loss: 62.4816, va c-index: 0.6944
# Counter 1 of 10
# epoch 25, tr_loss: 27.8405, va_loss: 62.3502, va c-index: 0.6716
# Counter 2 of 10
# epoch 26, tr_loss: 27.1598, va_loss: 62.6448, va c-index: 0.6824
# Counter 3 of 10
# epoch 27, tr_loss: 29.0299, va_loss: 62.4776, va c-index: 0.6724
# Counter 4 of 10
# epoch 28, tr_loss: 29.4693, va_loss: 60.6876, va c-index: 0.6397
# Counter 5 of 10
# epoch 29, tr_loss: 27.4862, va_loss: 64.6874, va c-index: 0.6663
# Counter 6 of 10
# epoch 30, tr_loss: 29.4606, va_loss: 62.2199, va c-index: 0.6736
# Counter 7 of 10
# epoch 31, tr_loss: 28.8250, va_loss: 62.4490, va c-index: 0.6816
# Counter 8 of 10
# epoch 32, tr_loss: 28.6683, va_loss: 62.7388, va c-index: 0.6228
# Counter 9 of 10
# epoch 33, tr_loss: 33.9417, va_loss: 60.6431, va c-index: 0.6821
#  26%|█████████████▍                                      | 14/54 [41:58<2:13:28, 200.21s/it]
# Counter 10 of 10
# Early stopping with best_cindex: 0.6944 and val_cindex for this epoch: 0.6774
# ================================================================================
#  {'beta': 0.5, 'dropout': 0.4, 'gamma': 0.1, 'lr_train': 0.001}
# updated.... average c-index = 0.6522
# epoch 1, tr_loss: 51.2963, va_loss: 63.6856, va c-index: 0.6522
# Counter 1 of 10
# epoch 2, tr_loss: 48.3548, va_loss: 62.1348, va c-index: 0.6137
# Counter 2 of 10
# epoch 3, tr_loss: 46.8988, va_loss: 62.8582, va c-index: 0.6299
# Counter 3 of 10
# epoch 4, tr_loss: 45.5321, va_loss: 60.8956, va c-index: 0.6320
# updated.... average c-index = 0.6848
# epoch 5, tr_loss: 45.3175, va_loss: 66.1968, va c-index: 0.6848
# Counter 1 of 10
# epoch 6, tr_loss: 47.1833, va_loss: 60.2790, va c-index: 0.6664
# Counter 2 of 10
# epoch 7, tr_loss: 43.1989, va_loss: 62.7338, va c-index: 0.6842
# Counter 3 of 10
# epoch 8, tr_loss: 43.9542, va_loss: 64.0769, va c-index: 0.6545
# Counter 4 of 10
# epoch 9, tr_loss: 42.3450, va_loss: 62.5165, va c-index: 0.6763
# Counter 5 of 10
# epoch 10, tr_loss: 48.3135, va_loss: 62.0628, va c-index: 0.6628
# Counter 6 of 10
# epoch 11, tr_loss: 42.8635, va_loss: 60.1592, va c-index: 0.6569
# Counter 7 of 10
# epoch 12, tr_loss: 40.8608, va_loss: 60.0128, va c-index: 0.6779
# Counter 8 of 10
# epoch 13, tr_loss: 42.6232, va_loss: 61.4580, va c-index: 0.6639
# updated.... average c-index = 0.6886
# epoch 14, tr_loss: 42.9032, va_loss: 61.5246, va c-index: 0.6886
# updated.... average c-index = 0.7034
# epoch 15, tr_loss: 42.2491, va_loss: 58.5900, va c-index: 0.7034
# updated.... average c-index = 0.7045
# epoch 16, tr_loss: 44.0347, va_loss: 59.5990, va c-index: 0.7045
# updated.... average c-index = 0.7087
# epoch 17, tr_loss: 41.1025, va_loss: 60.9521, va c-index: 0.7087
# updated.... average c-index = 0.7109
# epoch 18, tr_loss: 40.5642, va_loss: 61.8293, va c-index: 0.7109
# Counter 1 of 10
# epoch 19, tr_loss: 38.1233, va_loss: 62.5531, va c-index: 0.6408
# Counter 2 of 10
# epoch 20, tr_loss: 40.7208, va_loss: 62.1509, va c-index: 0.6581
# Counter 3 of 10
# epoch 21, tr_loss: 39.5399, va_loss: 61.0658, va c-index: 0.6790
# Counter 4 of 10
# epoch 22, tr_loss: 40.5720, va_loss: 63.0689, va c-index: 0.6853
# Counter 5 of 10
# epoch 23, tr_loss: 40.8500, va_loss: 58.3653, va c-index: 0.6799
# Counter 6 of 10
# epoch 24, tr_loss: 38.2011, va_loss: 63.6655, va c-index: 0.6571
# Counter 7 of 10
# epoch 25, tr_loss: 43.8351, va_loss: 60.9425, va c-index: 0.6882
# Counter 8 of 10
# epoch 26, tr_loss: 43.5108, va_loss: 63.3033, va c-index: 0.6880
# Counter 9 of 10
# epoch 27, tr_loss: 42.2218, va_loss: 59.5872, va c-index: 0.6950
#  28%|██████████████▍                                     | 15/54 [44:41<2:03:00, 189.24s/it]
# Counter 10 of 10
# Early stopping with best_cindex: 0.
# epoch 44, tr_loss: 92.1926, va_loss: 342.2103, va c-index: 0.6767
# Counter 5 of 10
# epoch 45, tr_loss: 90.1732, va_loss: 352.7618, va c-index: 0.6667
# Counter 6 of 10
# epoch 46, tr_loss: 87.9991, va_loss: 330.1135, va c-index: 0.6678
# Counter 7 of 10
# epoch 47, tr_loss: 87.0047, va_loss: 348.5537, va c-index: 0.6705
# Counter 8 of 10
# epoch 48, tr_loss: 88.2994, va_loss: 349.2517, va c-index: 0.6781
# Counter 9 of 10
# epoch 49, tr_loss: 89.3245, va_loss: 329.4568, va c-index: 0.6775
#  46%|███████████████████████▏                          | 25/54 [1:12:47<1:26:09, 178.27s/it]
# Counter 10 of 10
# Early stopping with best_cindex: 0.6793 and val_cindex for this epoch: 0.6723
# ================================================================================
#  {'beta': 1, 'dropout': 0.2, 'gamma': 0.5, 'lr_train': 0.0005}
# updated.... average c-index = 0.5759
# epoch 1, tr_loss: 151.7689, va_loss: 282.9630, va c-index: 0.5759
# updated.... average c-index = 0.5995
# epoch 2, tr_loss: 142.6212, va_loss: 312.6950, va c-index: 0.5995
# Counter 1 of 10
# epoch 3, tr_loss: 150.5140, va_loss: 283.3591, va c-index: 0.5363
# Counter 2 of 10
# epoch 4, tr_loss: 136.4515, va_loss: 301.4830, va c-index: 0.5530
# Counter 3 of 10
# epoch 5, tr_loss: 137.6825, va_loss: 330.9066, va c-index: 0.5529
# Counter 4 of 10
# epoch 6, tr_loss: 138.8768, va_loss: 309.0941, va c-index: 0.5511
# Counter 5 of 10
# epoch 7, tr_loss: 128.6332, va_loss: 304.3136, va c-index: 0.5405
# Counter 6 of 10
# epoch 8, tr_loss: 152.2822, va_loss: 292.7333, va c-index: 0.5218
# Counter 7 of 10
# epoch 9, tr_loss: 146.4389, va_loss: 299.0457, va c-index: 0.5265
# Counter 8 of 10
# epoch 10, tr_loss: 159.9199, va_loss: 331.2216, va c-index: 0.5320
# Counter 9 of 10
# epoch 11, tr_loss: 134.9566, va_loss: 304.8888, va c-index: 0.5422
#  48%|████████████████████████                          | 26/54 [1:14:14<1:10:26, 150.96s/it]
# Counter 10 of 10
# Early stopping with best_cindex: 0.5995 and val_cindex for this epoch: 0.5225
# ================================================================================
#  {'beta': 1, 'dropout': 0.2, 'gamma': 0.5, 'lr_train': 0.001}
# updated.... average c-index = 0.6299
# epoch 1, tr_loss: 205.1813, va_loss: 284.4098, va c-index: 0.6299
# Counter 1 of 10
# epoch 2, tr_loss: 214.8070, va_loss: 299.9201, va c-index: 0.5345
# Counter 2 of 10
# epoch 3, tr_loss: 208.3268, va_loss: 280.7289, va c-index: 0.3594
# Counter 3 of 10
# epoch 4, tr_loss: 213.5549, va_loss: 284.4718, va c-index: 0.3616
# Counter 4 of 10
# epoch 5, tr_loss: 211.2365, va_loss: 293.0811, va c-index: 0.3614
# Counter 5 of 10
# epoch 6, tr_loss: 201.4305, va_loss: 287.2241, va c-index: 0.3621
# Counter 6 of 10
# epoch 7, tr_loss: 204.9607, va_loss: 300.8508, va c-index: 0.3633
# Counter 7 of 10
# epoch 8, tr_loss: 194.3884, va_loss: 296.6799, va c-index: 0.3884
# Counter 8 of 10
# epoch 9, tr_loss: 190.6970, va_loss: 315.7277, va c-index: 0.3538
# Counter 9 of 10
# epoch 10, tr_loss: 185.3269, va_loss: 322.3084, va c-index: 0.3577
#  50%|██████████████████████████                          | 27/54 [1:15:37<58:49, 130.74s/it]
# Counter 10 of 10
# Early stopping with best_cindex: 0.6299 and val_cindex for this epoch: 0.3654
# ================================================================================
#  {'beta': 1, 'dropout': 0.4, 'gamma': 0.05, 'lr_train': 0.0001}
# updated.... average c-index = 0.5897
# epoch 1, tr_loss: 45.2333, va_loss: 47.3541, va c-index: 0.5897
# Counter 1 of 10
# epoch 2, tr_loss: 40.1580, va_loss: 44.2779, va c-index: 0.5751
# Counter 2 of 10
# epoch 3, tr_loss: 38.4982, va_loss: 41.5433, va c-index: 0.5538
# Counter 3 of 10
# epoch 4, tr_loss: 36.6623, va_loss: 40.6518, va c-index: 0.5564
# Counter 4 of 10
# epoch 5, tr_loss: 36.2480, va_loss: 40.8331, va c-index: 0.5372
# Counter 5 of 10
# epoch 6, tr_loss: 35.6411, va_loss: 40.3953, va c-index: 0.5438
# Counter 6 of 10
# epoch 7, tr_loss: 35.1649, va_loss: 40.1289, va c-index: 0.5504
# Counter 7 of 10
# epoch 8, tr_loss: 34.6219, va_loss: 39.8959, va c-index: 0.5583
# Counter 8 of 10
# epoch 9, tr_loss: 34.1414, va_loss: 39.5539, va c-index: 0.5707
# Counter 9 of 10
# epoch 10, tr_loss: 33.8205, va_loss: 39.2817, va c-index: 0.5864
#  52%|██████████████████████████▉                         | 28/54 [1:17:02<50:35, 116.75s/it]
# Counter 10 of 10
# Early stopping with best_cindex: 0.5897 and val_cindex for this epoch: 0.5775
# ================================================================================
#  {'beta': 1, 'dropout': 0.4, 'gamma': 0.05, 'lr_train': 0.0005}
# updated.... average c-index = 0.6385
# epoch 1, tr_loss: 33.8969, va_loss: 43.6298, va c-index: 0.6385
# Counter 1 of 10
# epoch 2, tr_loss: 29.7902, va_loss: 39.8372, va c-index: 0.6180
# updated.... average c-index = 0.6395
# epoch 3, tr_loss: 29.3989, va_loss: 39.5397, va c-index: 0.6395
# Counter 1 of 10
# epoch 4, tr_loss: 28.7069, va_loss: 38.8091, va c-index: 0.6378
# Counter 2 of 10
# epoch 5, tr_loss: 28.7981, va_loss: 39.5408, va c-index: 0.6034
# Counter 3 of 10
# epoch 6, tr_loss: 29.7172, va_loss: 40.8482, va c-index: 0.5708
# Counter 4 of 10
# epoch 7, tr_loss: 28.3005, va_loss: 39.7005, va c-index: 0.6088
# Counter 5 of 10
# epoch 8, tr_loss: 26.8548, va_loss: 39.4779, va c-index: 0.6112
# Counter 6 of 10
# epoch 9, tr_loss: 26.1046, va_loss: 41.2546, va c-index: 0.6291
# Counter 7 of 10
# epoch 10, tr_loss: 26.8416, va_loss: 42.5482, va c-index: 0.6007
# Counter 8 of 10
# epoch 11, tr_loss: 25.2099, va_loss: 40.2089, va c-index: 0.6226
# Counter 9 of 10
# epoch 12, tr_loss: 25.8067, va_loss: 41.5864, va c-index: 0.6374
# updated.... average c-index = 0.6462
# epoch 13, tr_loss: 23.8487, va_loss: 40.1571, va c-index: 0.6462
# updated.... average c-index = 0.6486
# epoch 14, tr_loss: 23.5205, va_loss: 40.2529, va c-index: 0.6486
# updated.... average c-index = 0.6633
# epoch 15, tr_loss: 24.1247, va_loss: 38.3234, va c-index: 0.6633
# Counter 1 of 10
# epoch 16, tr_loss: 22.0177, va_loss: 39.1125, va c-index: 0.6501
# updated.... average c-index = 0.6722
# epoch 17, tr_loss: 21.3729, va_loss: 38.3648, va c-index: 0.6722
# updated.... average c-index = 0.6783
# epoch 18, tr_loss: 22.3911, va_loss: 39.4628, va c-index: 0.6783
# Counter 1 of 10
# epoch 19, tr_loss: 21.2178, va_loss: 38.4310, va c-index: 0.6743
# Counter 2 of 10
# epoch 20, tr_loss: 21.6411, va_loss: 38.7364, va c-index: 0.6663
# Counter 3 of 10
# epoch 21, tr_loss: 21.0205, va_loss: 37.9099, va c-index: 0.6714
# updated.... average c-index = 0.6793
# epoch 22, tr_loss: 23.7860, va_loss: 38.0122, va c-index: 0.6793
# Counter 1 of 10
# epoch 23, tr_loss: 21.7244, va_loss: 38.4958, va c-index: 0.6736
# Counter 2 of 10
# epoch 24, tr_loss: 20.3500, va_loss: 40.6072, va c-index: 0.6768
# Counter 3 of 10
# epoch 25, tr_loss: 20.4272, va_loss: 39.6665, va c-index: 0.6668
# Counter 4 of 10
# epoch 26, tr_loss: 21.8679, va_loss: 38.4691, va c-index: 0.6706
# Counter 5 of 10
# epoch 27, tr_loss: 20.6642, va_loss: 38.8137, va c-index: 0.6783
# updated.... average c-index = 0.6847
# epoch 28, tr_loss: 20.4366, va_loss: 37.3281, va c-index: 0.6847
# Counter 1 of 10
# epoch 29, tr_loss: 20.4297, va_loss: 38.1849, va c-index: 0.6761
# Counter 2 of 10
# epoch 30, tr_loss: 20.1943, va_loss: 39.3661, va c-index: 0.6789
# Counter 3 of 10
# epoch 31, tr_loss: 21.0439, va_loss: 39.6317, va c-index: 0.6835
# updated.... average c-index = 0.6871
# epoch 32, tr_loss: 21.2672, va_loss: 41.0754, va c-index: 0.6871
# updated.... average c-index = 0.6871
# epoch 33, tr_loss: 20.8359, va_loss: 44.6467, va c-index: 0.6871
# Counter 1 of 10
# epoch 34, tr_loss: 20.7541, va_loss: 41.1173, va c-index: 0.6790
# updated.... average c-index = 0.6883
# epoch 35, tr_loss: 19.8056, va_loss: 40.0185, va c-index: 0.6883
# Counter 1 of 10
# epoch 36, tr_loss: 20.2662, va_loss: 37.6310, va c-index: 0.6832
# Counter 2 of 10
# epoch 37, tr_loss: 19.9492, va_loss: 38.8130, va c-index: 0.6865
# Counter 3 of 10
# epoch 38, tr_loss: 21.0235, va_loss: 38.7115, va c-index: 0.6553
# Counter 4 of 10
# epoch 39, tr_loss: 20.2245, va_loss: 41.7378, va c-index: 0.6812
# Counter 5 of 10
# epoch 40, tr_loss: 20.0386, va_loss: 40.7275, va c-index: 0.6649
# Counter 6 of 10
# epoch 41, tr_loss: 20.7033, va_loss: 38.0651, va c-index: 0.6861
# updated.... average c-index = 0.7004
# epoch 42, tr_loss: 19.4243, va_loss: 40.4930, va c-index: 0.7004
# Counter 1 of 10
# epoch 43, tr_loss: 20.1543, va_loss: 38.7109, va c-index: 0.6835
# updated.... average c-index = 0.7022
# epoch 44, tr_loss: 19.3083, va_loss: 40.1396, va c-index: 0.7022
# Counter 1 of 10
# epoch 45, tr_loss: 19.5927, va_loss: 39.9054, va c-index: 0.6803
# Counter 2 of 10
# epoch 46, tr_loss: 19.5114, va_loss: 37.3834, va c-index: 0.6837
# Counter 3 of 10
# epoch 47, tr_loss: 19.6407, va_loss: 37.4361, va c-index: 0.6705
# Counter 4 of 10
# epoch 48, tr_loss: 19.9341, va_loss: 37.7707, va c-index: 0.6753
# Counter 5 of 10
# epoch 49, tr_loss: 20.0555, va_loss: 38.3922, va c-index: 0.6833
# Counter 6 of 10
# epoch 50, tr_loss: 19.5225, va_loss: 36.9040, va c-index: 0.6814
# Counter 7 of 10
# epoch 51, tr_loss: 18.7826, va_loss: 37.9412, va c-index: 0.6737
# Counter 8 of 10
# epoch 52, tr_loss: 18.6322, va_loss: 36.8572, va c-index: 0.6680
# Counter 9 of 10
# epoch 53, tr_loss: 18.4783, va_loss: 37.4216, va c-index: 0.6792
#  54%|██████████████████████████▊                       | 29/54 [1:21:45<1:09:29, 166.76s/it]
# Counter 10 of 10
# Early stopping with best_cindex: 0.7022 and val_cindex for this epoch: 0.6810
# ================================================================================
#  {'beta': 1, 'dropout': 0.4, 'gamma': 0.05, 'lr_train': 0.001}
# updated.... average c-index = 0.5753
# epoch 1, tr_loss: 37.3326, va_loss: 42.7602, va c-index: 0.5753
# updated.... average c-index = 0.6328
# epoch 2, tr_loss: 34.3897, va_loss: 40.4844, va c-index: 0.6328
# Counter 1 of 10
# epoch 3, tr_loss: 34.1918, va_loss: 39.5611, va c-index: 0.5941
# Counter 2 of 10
# epoch 4, tr_loss: 31.7399, va_loss: 38.6338, va c-index: 0.6258
# Counter 3 of 10
# epoch 5, tr_loss: 32.0524, va_loss: 38.6383, va c-index: 0.5962
# Counter 4 of 10
# epoch 6, tr_loss: 31.2655, va_loss: 38.1040, va c-index: 0.6324
# updated.... average c-index = 0.6347
# epoch 7, tr_loss: 31.5855, va_loss: 37.9615, va c-index: 0.6347
# Counter 1 of 10
# epoch 8, tr_loss: 31.9071, va_loss: 38.4120, va c-index: 0.6308
# updated.... average c-index = 0.6569
# epoch 9, tr_loss: 29.9938, va_loss: 37.4148, va c-index: 0.6569
# updated.... average c-index = 0.6761
# epoch 10, tr_loss: 29.6775, va_loss: 37.0144, va c-index: 0.6761
# updated.... average c-index = 0.6811
# epoch 11, tr_loss: 27.1196, va_loss: 37.9429, va c-index: 0.6811
# Counter 1 of 10
# epoch 12, tr_loss: 43.0027, va_loss: 48.2837, va c-index: 0.5326
# Counter 2 of 10
# epoch 13, tr_loss: 39.4909, va_loss: 48.5940, va c-index: 0.2931
# Counter 3 of 10
# epoch 14, tr_loss: 40.4693, va_loss: 51.6315, va c-index: 0.2958
# Counter 4 of 10
# epoch 15, tr_loss: 41.0351, va_loss: 47.4993, va c-index: 0.2958
# Counter 5 of 10
# epoch 16, tr_loss: 40.7500, va_loss: 47.1852, va c-index: 0.2958
# Counter 6 of 10
# epoch 17, tr_loss: 40.1118, va_loss: 48.0963, va c-index: 0.2958
# Counter 7 of 10
# epoch 18, tr_loss: 40.6530, va_loss: 50.3411, va c-index: 0.2971
# Counter 8 of 10
# epoch 19, tr_loss: 41.3526, va_loss: 49.9402, va c-index: 0.2989
# Counter 9 of 10
# epoch 20, tr_loss: 39.1658, va_loss: 48.7486, va c-index: 0.2990
#  56%|███████████████████████████▊                      | 30/54 [1:23:51<1:01:52, 154.67s/it]
# Counter 10 of 10
# Early stopping with best_cindex: 0.6811 and val_cindex for this epoch: 0.2930
# ================================================================================
#  {'beta': 1, 'dropout': 0.4, 'gamma': 0.1, 'lr_train': 0.0001}
# updated.... average c-index = 0.5018
# epoch 1, tr_loss: 61.0642, va_loss: 67.7218, va c-index: 0.5018
# updated.... average c-index = 0.5414
# epoch 2, tr_loss: 56.8409, va_loss: 67.2079, va c-index: 0.5414
# Counter 1 of 10
# epoch 3, tr_loss: 56.2519, va_loss: 66.4977, va c-index: 0.5386
# updated.... average c-index = 0.5494
# epoch 4, tr_loss: 54.9938, va_loss: 66.2892, va c-index: 0.5494
# updated.... average c-index = 0.5577
# epoch 5, tr_loss: 54.6680, va_loss: 65.8139, va c-index: 0.5577
# updated.... average c-index = 0.5586
# epoch 6, tr_loss: 54.3779, va_loss: 65.5380, va c-index: 0.5586
# Counter 1 of 10
# epoch 7, tr_loss: 54.9518, va_loss: 65.8667, va c-index: 0.5553
# updated.... average c-index = 0.5610
# epoch 8, tr_loss: 53.9554, va_loss: 66.1899, va c-index: 0.5610
# Counter 1 of 10
# epoch 9, tr_loss: 54.2507, va_loss: 66.6523, va c-index: 0.5604
# updated.... average c-index = 0.5620
# epoch 10, tr_loss: 54.4392, va_loss: 66.8132, va c-index: 0.5620
# Counter 1 of 10
# epoch 11, tr_loss: 53.7285, va_loss: 66.9441, va c-index: 0.5589

# %%
model
# Out:
# DynamicDeepHitTorch(
#   (embedding): LSTM(116, 64, num_layers=2, bias=False, batch_first=True)
#   (longitudinal): Sequential(
#     (0): Dropout(p=0.4, inplace=False)
#     (1): Linear(in_features=64, out_features=64, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#     (5): Linear(in_features=64, out_features=116, bias=True)
#   )
#   (attention): Sequential(
#     (0): Dropout(p=0.4, inplace=False)
#     (1): Linear(in_features=180, out_features=64, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#     (5): Linear(in_features=64, out_features=1, bias=True)
#   )
#   (attention_soft): Softmax(dim=1)
#   (cause_specific): ModuleList(
#     (0): Sequential(
#       (0): Dropout(p=0.4, inplace=False)
#       (1): Linear(in_features=180, out_features=64, bias=True)
#       (2): ReLU()
#       (3): Linear(in_features=64, out_features=64, bias=True)
#       (4): ReLU()
#       (5): Linear(in_features=64, out_features=120, bias=True)
#     )
#     (1): Sequential(
#       (0): Dropout(p=0.4, inplace=False)
#       (1): Linear(in_features=180, out_features=64, bias=True)
#       (2): ReLU()
#       (3): Linear(in_features=64, out_features=64, bias=True)
#       (4): ReLU()
#       (5): Linear(in_features=64, out_features=120, bias=True)
#     )
#     (2): Sequential(
#       (0): Dropout(p=0.4, inplace=False)
#       (1): Linear(in_features=180, out_features=64, bias=True)
#       (2): ReLU()
#       (3): Linear(in_features=64, out_features=64, bias=True)
#       (4): ReLU()
#       (5): Linear(in_features=64, out_features=120, bias=True)
#     )
#   )
#   (soft): Softmax(dim=-1)
# )

# %% [markdown]
# ### Test the Trained Network
# see the code in `eval-ddh.ipynb` file
